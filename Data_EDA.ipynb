# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /Users/owner/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # **Load data**

# %%
df = pd.read_csv('data/step2_output.csv',sep='\t')

# %%
# Check out its appearance. 
df.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own      No Account           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little       No Account           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose  Risk
# 0         6             radio/TV  good
# 1        48             radio/TV   bad
# 2        12            education  good
# 3        42  furniture/equipment  good
# 4        24                  car   bad

# %%
df.describe()
# Out:
#                Age          Job  Credit amount     Duration
# count  1000.000000  1000.000000    1000.000000  1000.000000
# mean     35.546000     1.904000    3271.258000    20.903000
# std      11.375469     0.653614    2822.736876    12.058814
# min      19.000000     0.000000     250.000000     4.000000
# 25%      27.000000     2.000000    1365.500000    12.000000
# 50%      33.000000     2.000000    2319.500000    18.000000
# 75%      42.000000     2.000000    3972.250000    24.000000
# max      75.000000     3.000000   18424.000000    72.000000

# %%
# histogram plot
ax = df['Age'].hist(bins=20)
ax.set_xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Job', 'Housing', 'Saving accounts', 'Checking account',
#        'Credit amount', 'Duration', 'Purpose', 'Risk'],
#       dtype='object')

# %%
# histogram plot
ax = df['Job'].hist()
ax.set_xlabel("No. of jobs")
# Out:
# Text(0.5, 0, 'No. of jobs')

# %%
# histogram plot
ax = df['Credit amount'].hist(bins=20)
ax.set_xlabel("Credit amount")
# Out:
# Text(0.5, 0, 'Credit amount')

# %%
# histogram plot
ax = df['Duration'].hist(bins=20)
ax.set_xlabel("Duration in months")
# Out:
# Text(0.5, 0, 'Duration in months')

# %%
# pairplot
g=sns.pairplot(df)
plt.savefig('figures/pairplot.png', bbox_inches='tight')

# %%
#Calculate the correlation coefficients
corr = df.corr(method='pearson')
#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row1_col0 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row1_col2 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row1_col3 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row2_col0 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row2_col1 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row2_col3 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row3_col1 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row3_col2 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_0670ef92_1e42_11eb_84d1_0c4de9a89585row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age</th>        <th class="col_heading level0 col1" >Job</th>        <th class="col_heading level0 col2" >Credit amount</th>        <th class="col_heading level0 col3" >Duration</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585level0_row0" class="row_heading level0 row0" >Age</th>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row0_col1" class="data row0 col1" >0.020000</td>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row0_col2" class="data row0 col2" >0.030000</td>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row0_col3" class="data row0 col3" >-0.040000</td>
#             </tr>
#             <tr>
#                         <th id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585level0_row1" class="row_heading level0 row1" >Job</th>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row1_col0" class="data row1 col0" >0.020000</td>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row1_col2" class="data row1 col2" >0.290000</td>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row1_col3" class="data row1 col3" >0.210000</td>
#             </tr>
#             <tr>
#                         <th id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585level0_row2" class="row_heading level0 row2" >Credit amount</th>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row2_col0" class="data row2 col0" >0.030000</td>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row2_col1" class="data row2 col1" >0.290000</td>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row2_col3" class="data row2 col3" >0.620000</td>
#             </tr>
#             <tr>
#                         <th id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585level0_row3" class="row_heading level0 row3" >Duration</th>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row3_col0" class="data row3 col0" >-0.040000</td>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row3_col1" class="data row3 col1" >0.210000</td>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row3_col2" class="data row3 col2" >0.620000</td>
#                         <td id="T_0670ef92_1e42_11eb_84d1_0c4de9a89585row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
# Box plots
df_list = list(df.describe().columns)
for i in df_list:
    plt.figure()
    df[i].plot.box()
    plt.show

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(5, 5))

# In the following brackets, we want the value_counts() of the sex 
x = pd.DataFrame(df.Sex.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.Sex into the list() function
values = list(x.Sex)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="coolwarm")

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(5, 5))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(df.Housing.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.Housing into the list() function
values = list(x.Housing)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="coolwarm")

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the saving accounts
x = pd.DataFrame(df['Saving accounts'].value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.Housing into the list() function
values = list(x['Saving accounts'])

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="coolwarm")

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the saving accounts
x = pd.DataFrame(df['Checking account'].value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.Housing into the list() function
values = list(x['Checking account'])

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="coolwarm")

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the saving accounts
x = pd.DataFrame(df['Purpose'].value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.Housing into the list() function
values = list(x['Purpose'])

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="coolwarm")

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the saving accounts
x = pd.DataFrame(df['Risk'].value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.Housing into the list() function
values = list(x['Risk'])

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="coolwarm")

# %%
# Save data
path = os.getcwd()
directory = "data"
data_dir = os.path.join(path, directory)
df.to_csv(os.path.join(data_dir,'step3_output.csv'),sep='\t',index=False)
